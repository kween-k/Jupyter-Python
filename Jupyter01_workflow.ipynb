# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
URL = pd.read_json('https://data.seattle.gov/resource/4xy5-26gy.json')

# %%
df = pd.DataFrame(URL)
df.set_index('date', inplace=True)
print(df.head())
# Out:
#                      fremont_bridge_nb  fremont_bridge_sb
# date
# 2015-02-24 02:00:00                  3                  3
# 2017-01-09 06:00:00                 55                 28
# 2012-12-02 14:00:00                 25                 16
# 2016-02-15 00:00:00                  3                  3
# 2015-12-18 21:00:00                  7                 17

# %%
df.plot()
plt.show()

# %%
#To see a little better, we can resample using sum
df.resample('W').sum().plot();

# %%
from matplotlib import style
style.use('ggplot')

# %%
df.plot()
plt.show()

# %%
import json
URL = pd.read_json('https://data.seattle.gov/resource/4xy5-26gy.json')

# %%
URL.to_csv('Fremont.csv')
URL.to_json('Fremont.json')
